# %%
import pandas as pd

df = pd.read_csv("D:/Rhapsody/Rhapsody/GLUT1_ave_poly.csv", delimiter=";")

grouped = df.groupby('PolyPhen-2')

for key, group in grouped:
    l = []
    for index, row in group.iterrows():
        l.append(row['Label.1'])
    print(f" {key}: {l}")
# Out:
#  0,02: ['V']
#  0,03: ['Q']
#  0,05: ['K', 'Q']
#  0,06: ['G', 'Q', 'P']
#  0,07: ['A', 'A']
#  0,08: ['T', 'A', 'H']
#  0,09: ['L', 'G', 'S', 'E']
#  0,11: ['S', 'T']
#  0,12: ['P', 'Q', 'D']
#  0,13: ['H', 'S', 'S', 'E', 'S']
#  0,14: ['K', 'S', 'Q', 'S']
#  0,15: ['Q', 'T', 'H']
#  0,16: ['S', 'G', 'K']
#  0,17: ['S', 'P', 'M', 'D', 'N', 'Q', 'A', 'G']
#  0,18: ['E', 'S']
#  0,19: ['E']
#  0,2: ['T']
#  0,21: ['R', 'M', 'L']
#  0,22: ['G', 'E']
#  0,23: ['P', 'G', 'K', 'P', 'A']
#  0,24: ['G', 'T', 'P']
#  0,25: ['I', 'G', 'F']
#  0,26: ['K', 'S']
#  0,27: ['E', 'E', 'D']
#  0,28: ['Q']
#  0,29: ['S', 'R']
#  0,3: ['C']
#  0,32: ['A', 'R', 'Q', 'P', 'E']
#  0,33: ['M', 'L']
#  0,34: ['T', 'G']
#  0,35: ['L']
#  0,37: ['G']
#  0,38: ['Y', 'T', 'C', 'V', 'L']
#  0,39: ['M', 'N']
#  0,4: ['A', 'I']
#  0,41: ['D', 'K', 'R']
#  0,42: ['L', 'L']
#  0,43: ['K', 'N', 'T', 'V']
#  0,44: ['K', 'R']
#  0,45: ['V', 'E', 'E', 'A']
#  0,46: ['C', 'L', 'C']
#  0,47: ['I', 'N', 'S', 'I', 'S']
# ...
